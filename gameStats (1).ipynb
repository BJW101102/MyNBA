# %%
import requests
import json

def get_games_by_team(team_id, season):
    """
    Retrieves all games for a specific team during input season.

    Args:
        team_id (int): The ID of the NBA team.
        season (str): The desired season (e.g., "2023").

    Returns:
        dict: A dictionary containing game statistics.
    """
    url = "https://api-nba-v1.p.rapidapi.com/games"
    querystring = {"team": str(team_id), "season": str(season)}

    headers = {
        "X-RapidAPI-Key": "49fd3143cfmshec3bdbb4c25a433p1753c9jsnf71b1dbb7945",
        "X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
    }

    try:
        response = requests.get(url, headers=headers, params=querystring)
        games = response.json()

        # Save the data to a JSON file
        with open("gameStats.json", "w") as json_file:
            json.dump(games, json_file, indent=4)  # Indent for readability

        print("Game stats saved to games.json")
        return games

    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return None

# Example usage:
team_id = 1  # Replace with the actual team ID
season = "2023"  # Replace with the desired season

game_stats = get_games_by_team(team_id, season)
if game_stats:
    print("Player games for Team", team_id)
    print(json.dumps(game_stats, indent=4))  # Print in a readable format
else:
    print("Failed to retrieve game stats.")
# Out:
# Game stats saved to games.json
# Player games for Team 1
# {
#     "get": "games/",
#     "parameters": {
#         "team": "1",
#         "season": "2023"
#     },
#     "errors": [],
#     "results": 87,
#     "response": [
#         {
#             "id": 12490,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-10T23:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 1,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 7,
#                     "name": "Cleveland Cavaliers",
#                     "nickname": "Cavaliers",
#                     "code": "CLE",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/0/06/Cavs_de_Cleveland_logo_2017.png/150px-Cavs_de_Cleveland_logo_2017.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "25",
#                         "20",
#                         "35",
#                         "27"
#                     ],
#                     "points": 107
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "26",
#                         "31",
#                         "20",
#                         "31"
#                     ],
#                     "points": 108
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12503,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-12T23:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 1,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 1,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 19,
#                     "name": "Memphis Grizzlies",
#                     "nickname": "Grizzlies",
#                     "code": "MEM",
#                     "logo": "https://upload.wikimedia.org/wikipedia/en/thumb/f/f1/Memphis_Grizzlies.svg/1200px-Memphis_Grizzlies.svg.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "31",
#                         "19",
#                         "23",
#                         "29"
#                     ],
#                     "points": 102
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "29",
#                         "30",
#                         "25",
#                         "19"
#                     ],
#                     "points": 103
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12510,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-14T19:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 1,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Gateway Center",
#                 "city": "College Park",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 23,
#                     "name": "New Orleans Pelicans",
#                     "nickname": "Pelicans",
#                     "code": "NOP",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "21",
#                         "15",
#                         "35",
#                         "34"
#                     ],
#                     "points": 105
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "28",
#                         "26",
#                         "28",
#                         "28"
#                     ],
#                     "points": 110
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12520,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-16T23:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 1,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Gainbridge Fieldhouse",
#                 "city": "Indianapolis",
#                 "state": "IN",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 15,
#                     "name": "Indiana Pacers",
#                     "nickname": "Pacers",
#                     "code": "IND",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/c/cf/Pacers_de_l%27Indiana_logo.svg/1180px-Pacers_de_l%27Indiana_logo.svg.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "31",
#                         "15",
#                         "35",
#                         "31"
#                     ],
#                     "points": 112
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "30",
#                         "43",
#                         "21",
#                         "22"
#                     ],
#                     "points": 116
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12543,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-20T23:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 1,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 3,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Wells Fargo Center",
#                 "city": "Philadelphia",
#                 "state": "PA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 27,
#                     "name": "Philadelphia 76ers",
#                     "nickname": "76ers",
#                     "code": "PHI",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/4/48/76ers_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "25",
#                         "36",
#                         "30",
#                         "15"
#                     ],
#                     "points": 106
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "24",
#                         "25",
#                         "38",
#                         "33"
#                     ],
#                     "points": 120
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12551,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-25T23:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Spectrum Center",
#                 "city": "Charlotte",
#                 "state": "NC",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 5,
#                     "name": "Charlotte Hornets",
#                     "nickname": "Hornets",
#                     "code": "CHA",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/f/f3/Hornets_de_Charlotte_logo.svg/1200px-Hornets_de_Charlotte_logo.svg.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "29",
#                         "23",
#                         "21",
#                         "37"
#                     ],
#                     "points": 110
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "25",
#                         "26",
#                         "27",
#                         "38"
#                     ],
#                     "points": 116
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12567,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-27T23:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 24,
#                     "name": "New York Knicks",
#                     "nickname": "Knicks",
#                     "code": "NYK",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/3/34/Knicks_de_NY.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "35",
#                         "34",
#                         "31",
#                         "26"
#                     ],
#                     "points": 126
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "31",
#                         "30",
#                         "31",
#                         "28"
#                     ],
#                     "points": 120
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12585,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-29T23:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Fiserv Forum",
#                 "city": "Milwaukee",
#                 "state": "WI",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 21,
#                     "name": "Milwaukee Bucks",
#                     "nickname": "Bucks",
#                     "code": "MIL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/3/34/Bucks2015.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "31",
#                         "37",
#                         "33",
#                         "26"
#                     ],
#                     "points": 127
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "25",
#                         "22",
#                         "33",
#                         "30"
#                     ],
#                     "points": 110
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12592,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-10-30T23:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 22,
#                     "name": "Minnesota Timberwolves",
#                     "nickname": "Timberwolves",
#                     "code": "MIN",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "42",
#                         "37",
#                         "19",
#                         "15"
#                     ],
#                     "points": 113
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "35",
#                         "25",
#                         "38",
#                         "29"
#                     ],
#                     "points": 127
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12605,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-01T23:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 41,
#                     "name": "Washington Wizards",
#                     "nickname": "Wizards",
#                     "code": "WAS",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/archive/d/d6/20161212034849%21Wizards2015.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "30",
#                         "21",
#                         "31",
#                         "39"
#                     ],
#                     "points": 121
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "25",
#                         "34",
#                         "40",
#                         "31"
#                     ],
#                     "points": 130
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12630,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-04T23:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Smoothie King Center",
#                 "city": "New Orleans",
#                 "state": "LA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 23,
#                     "name": "New Orleans Pelicans",
#                     "nickname": "Pelicans",
#                     "code": "NOP",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/2/21/New_Orleans_Pelicans.png/200px-New_Orleans_Pelicans.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "27",
#                         "26",
#                         "41",
#                         "29"
#                     ],
#                     "points": 123
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "35",
#                         "25",
#                         "23",
#                         "22"
#                     ],
#                     "points": 105
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12650,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-07T01:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Paycom Center",
#                 "city": "Oklahoma City",
#                 "state": "OK",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 25,
#                     "name": "Oklahoma City Thunder",
#                     "nickname": "Thunder",
#                     "code": "OKC",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/4/4f/Thunder_d%27Oklahoma_City_logo.svg/1200px-Thunder_d%27Oklahoma_City_logo.svg.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "28",
#                         "22",
#                         "27",
#                         "40"
#                     ],
#                     "points": 117
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "29",
#                         "29",
#                         "38",
#                         "30"
#                     ],
#                     "points": 126
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12667,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-10T02:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Mexico City Arena",
#                 "city": "Mexico City",
#                 "state": null,
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 26,
#                     "name": "Orlando Magic",
#                     "nickname": "Magic",
#                     "code": "ORL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/b/bd/Orlando_Magic_logo_2010.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "34",
#                         "39",
#                         "20",
#                         "27"
#                     ],
#                     "points": 120
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "34",
#                         "35",
#                         "29",
#                         "21"
#                     ],
#                     "points": 119
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12679,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-12T00:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 20,
#                     "name": "Miami Heat",
#                     "nickname": "Heat",
#                     "code": "MIA",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/1/1c/Miami_Heat_-_Logo.svg/1200px-Miami_Heat_-_Logo.svg.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "41",
#                         "22",
#                         "30",
#                         "24"
#                     ],
#                     "points": 117
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "24",
#                         "28",
#                         "30",
#                         "27"
#                     ],
#                     "points": 109
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12697,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-15T00:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Little Caesars Arena",
#                 "city": "Detroit",
#                 "state": "MI",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 10,
#                     "name": "Detroit Pistons",
#                     "nickname": "Pistons",
#                     "code": "DET",
#                     "logo": "https://upload.wikimedia.org/wikipedia/commons/thumb/3/39/Logo_of_the_Detroit_Pistons.png/300px-Logo_of_the_Detroit_Pistons.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "38",
#                         "26",
#                         "33",
#                         "29"
#                     ],
#                     "points": 126
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "29",
#                         "31",
#                         "31",
#                         "29"
#                     ],
#                     "points": 120
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12707,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-16T00:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 24,
#                     "name": "New York Knicks",
#                     "nickname": "Knicks",
#                     "code": "NYK",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/3/34/Knicks_de_NY.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "33",
#                         "24",
#                         "30",
#                         "29"
#                     ],
#                     "points": 116
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "22",
#                         "34",
#                         "25",
#                         "33"
#                     ],
#                     "points": 114
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12718,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-18T00:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 27,
#                     "name": "Philadelphia 76ers",
#                     "nickname": "76ers",
#                     "code": "PHI",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/4/48/76ers_2016.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "30",
#                         "27",
#                         "37",
#                         "32"
#                     ],
#                     "points": 126
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "24",
#                         "32",
#                         "31",
#                         "29"
#                     ],
#                     "points": 116
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12751,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-22T00:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 15,
#                     "name": "Indiana Pacers",
#                     "nickname": "Pacers",
#                     "code": "IND",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/c/cf/Pacers_de_l%27Indiana_logo.svg/1180px-Pacers_de_l%27Indiana_logo.svg.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "34",
#                         "39",
#                         "46",
#                         "38"
#                     ],
#                     "points": 157
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "40",
#                         "46",
#                         "28",
#                         "38"
#                     ],
#                     "points": 152
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12757,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-23T00:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 4,
#                     "name": "Brooklyn Nets",
#                     "nickname": "Nets",
#                     "code": "BKN",
#                     "logo": "https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Brooklyn_Nets_newlogo.svg/130px-Brooklyn_Nets_newlogo.svg.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "33",
#                         "34",
#                         "28",
#                         "36",
#                         "14"
#                     ],
#                     "points": 145
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "45",
#                         "32",
#                         "23",
#                         "31",
#                         "16"
#                     ],
#                     "points": 147
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 12781,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-11-26T00:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Capital One Arena",
#                 "city": "Washington",
#                 "state": "DC",
#                 "country": null
#             },
# ...
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Ball Arena",
#                 "city": "Denver",
#                 "state": "CO",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 9,
#                     "name": "Denver Nuggets",
#                     "nickname": "Nuggets",
#                     "code": "DEN",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/3/35/Nuggets_de_Denver_2018.png/180px-Nuggets_de_Denver_2018.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "26",
#                         "30",
#                         "30",
#                         "24"
#                     ],
#                     "points": 110
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "33",
#                         "36",
#                         "42",
#                         "31"
#                     ],
#                     "points": 142
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 13695,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2024-04-09T23:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 1,
#                 "long": "Scheduled"
#             },
#             "periods": {
#                 "current": 0,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 20,
#                     "name": "Miami Heat",
#                     "nickname": "Heat",
#                     "code": "MIA",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/1/1c/Miami_Heat_-_Logo.svg/1200px-Miami_Heat_-_Logo.svg.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 },
#                 "home": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 13707,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2024-04-10T23:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 1,
#                 "long": "Scheduled"
#             },
#             "periods": {
#                 "current": 0,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 5,
#                     "name": "Charlotte Hornets",
#                     "nickname": "Hornets",
#                     "code": "CHA",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/f/f3/Hornets_de_Charlotte_logo.svg/1200px-Hornets_de_Charlotte_logo.svg.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 },
#                 "home": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 13726,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2024-04-13T00:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 1,
#                 "long": "Scheduled"
#             },
#             "periods": {
#                 "current": 0,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Target Center",
#                 "city": "Minneapolis",
#                 "state": "MN",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 22,
#                     "name": "Minnesota Timberwolves",
#                     "nickname": "Timberwolves",
#                     "code": "MIN",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/d/d9/Timberwolves_du_Minnesota_logo_2017.png/200px-Timberwolves_du_Minnesota_logo_2017.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 },
#                 "home": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 13736,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2024-04-14T17:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 1,
#                 "long": "Scheduled"
#             },
#             "periods": {
#                 "current": 0,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Gainbridge Fieldhouse",
#                 "city": "Indianapolis",
#                 "state": "IN",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 15,
#                     "name": "Indiana Pacers",
#                     "nickname": "Pacers",
#                     "code": "IND",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/thumb/c/cf/Pacers_de_l%27Indiana_logo.svg/1180px-Pacers_de_l%27Indiana_logo.svg.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 },
#                 "home": {
#                     "win": null,
#                     "loss": null,
#                     "series": {
#                         "win": null,
#                         "loss": null
#                     },
#                     "linescore": [],
#                     "points": null
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 13757,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-12-07T00:30:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "State Farm Arena",
#                 "city": "Atlanta",
#                 "state": "GA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 4,
#                     "name": "Brooklyn Nets",
#                     "nickname": "Nets",
#                     "code": "BKN",
#                     "logo": "https://upload.wikimedia.org/wikipedia/commons/thumb/4/44/Brooklyn_Nets_newlogo.svg/130px-Brooklyn_Nets_newlogo.svg.png"
#                 },
#                 "home": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "31",
#                         "22",
#                         "28",
#                         "33"
#                     ],
#                     "points": 114
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "33",
#                         "23",
#                         "26",
#                         "31"
#                     ],
#                     "points": 113
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         },
#         {
#             "id": 13766,
#             "league": "standard",
#             "season": 2023,
#             "date": {
#                 "start": "2023-12-09T00:00:00.000Z",
#                 "end": null,
#                 "duration": null
#             },
#             "stage": 2,
#             "status": {
#                 "clock": null,
#                 "halftime": false,
#                 "short": 3,
#                 "long": "Finished"
#             },
#             "periods": {
#                 "current": 4,
#                 "total": 4,
#                 "endOfPeriod": false
#             },
#             "arena": {
#                 "name": "Wells Fargo Center",
#                 "city": "Philadelphia",
#                 "state": "PA",
#                 "country": null
#             },
#             "teams": {
#                 "visitors": {
#                     "id": 1,
#                     "name": "Atlanta Hawks",
#                     "nickname": "Hawks",
#                     "code": "ATL",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/e/ee/Hawks_2016.png"
#                 },
#                 "home": {
#                     "id": 27,
#                     "name": "Philadelphia 76ers",
#                     "nickname": "76ers",
#                     "code": "PHI",
#                     "logo": "https://upload.wikimedia.org/wikipedia/fr/4/48/76ers_2016.png"
#                 }
#             },
#             "scores": {
#                 "visitors": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "23",
#                         "45",
#                         "24",
#                         "22"
#                     ],
#                     "points": 114
#                 },
#                 "home": {
#                     "win": 0,
#                     "loss": 0,
#                     "series": {
#                         "win": 0,
#                         "loss": 0
#                     },
#                     "linescore": [
#                         "35",
#                         "27",
#                         "31",
#                         "32"
#                     ],
#                     "points": 125
#                 }
#             },
#             "officials": [],
#             "timesTied": null,
#             "leadChanges": null,
#             "nugget": null
#         }
#     ]
# }

# %%
import requests
import json

class Game:
    def __init__(self, game_id, date, arena_name, city, state, country, home_team, visitor_team, home_score, visitor_score):
        self.game_id = game_id
        self.date = date
        self.arena_name = arena_name
        self.city = city
        self.state = state
        self.country = country
        self.home_team = home_team
        self.visitor_team = visitor_team
        self.home_score = home_score
        self.visitor_score = visitor_score

def get_games_by_team(team_id, season):
    """
    Retrieves all games for a specific team during input season.
    Args:
        team_id (int): The ID of the NBA team.
        season (str): The desired season (e.g., "2023").
    Returns:
        list: A list of Game objects containing game statistics.
    """
    url = "https://api-nba-v1.p.rapidapi.com/games"
    querystring = {"team": str(team_id), "season": str(season)}
    headers = {
        "X-RapidAPI-Key": "49fd3143cfmshec3bdbb4c25a433p1753c9jsnf71b1dbb7945",
        "X-RapidAPI-Host": "api-nba-v1.p.rapidapi.com"
    }

    try:
        response = requests.get(url, headers=headers, params=querystring)
        games_data = response.json()["response"]
        games_list = []
        for game in games_data:
            game_obj = Game(
                game_id=game["id"],
                date=game["date"]["start"],
                arena_name=game["arena"]["name"],
                city=game["arena"]["city"],
                state=game["arena"]["state"],
                country=game["arena"]["country"],
                home_team=game["teams"]["home"]["name"],
                visitor_team=game["teams"]["visitors"]["name"],
                home_score=game["scores"]["home"]["points"],
                visitor_score=game["scores"]["visitors"]["points"]
            )
            games_list.append(game_obj)
        return games_list
    except requests.RequestException as e:
        print(f"Error fetching data: {e}")
        return []

# Example usage:
team_id = 1  # Replace with the actual team ID
season = "2023"  # Replace with the desired season
games_list = get_games_by_team(team_id, season)

if games_list:
    print(f"Number of games: {len(games_list)}")
    for game in games_list:
        print(f"Game ID: {game.game_id}, Date: {game.date}, Arena: {game.arena_name}, City: {game.city}, State: {game.state}, Country: {game.country}, Home Team: {game.home_team}, Visitor Team: {game.visitor_team}, Home Score: {game.home_score}, Visitor Score: {game.visitor_score}")
else:
    print("Failed to retrieve game stats.")
# Out:
# Number of games: 87
# Game ID: 12490, Date: 2023-10-10T23:30:00.000Z, Arena: State Farm Arena, City: Atlanta, State: GA, Country: None, Home Team: Atlanta Hawks, Visitor Team: Cleveland Cavaliers, Home Score: 108, Visitor Score: 107
# Game ID: 12503, Date: 2023-10-12T23:30:00.000Z, Arena: State Farm Arena, City: Atlanta, State: GA, Country: None, Home Team: Atlanta Hawks, Visitor Team: Memphis Grizzlies, Home Score: 103, Visitor Score: 102
# Game ID: 12510, Date: 2023-10-14T19:30:00.000Z, Arena: Gateway Center, City: College Park, State: GA, Country: None, Home Team: Atlanta Hawks, Visitor Team: New Orleans Pelicans, Home Score: 110, Visitor Score: 105
